# %%
# %cd "/content/drive/MyDrive/Pneumonia_Project/Models/chest-xray-pneumonia-detection-ai-main"
# !ls scripts
# Out:
# /content/drive/MyDrive/Pneumonia_Project/Models/chest-xray-pneumonia-detection-ai-main
# ls: cannot access 'scripts': No such file or directory

# %%
# %cd "/content/drive/MyDrive/Pneumonia_Project/Models/chest-xray-pneumonia-detection-ai-main/chest-xray-pneumonia-detection-ai-main"
# Out:
# /content/drive/MyDrive/Pneumonia_Project/Models/chest-xray-pneumonia-detection-ai-main/chest-xray-pneumonia-detection-ai-main

# %%
# !ls
# Out:
# api  demo  LICENSE  README.md  requirements.txt  results  scripts

# %%
# !ls scripts
# Out:
# analyze_and_balance.py	    cross-operator_validation.py  train_model.py
# create_balanced_dataset.py  evaluate_model.py

# %%
# !ls scripts
# Out:
# ls: cannot access 'scripts': No such file or directory

# %%
# !python scripts/train_model.py
# Out:
# 2026-02-17 19:46:31.100206: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 19:46:31.106878: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-17 19:46:31.122139: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771357591.148377    7438 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771357591.155568    7438 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip install tensorflow pandas numpy matplotlib scikit-learn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
